# %%
import argparse
from tqdm import tqdm
import numpy as np
import sys

from tot.methods.bfs import solve, naive_solve
from tot.tasks.game24 import Game24Task
# Out:
# Warning: OPENAI_API_KEY is not set

# %%
import sys
print(sys.executable)

import tot
print(tot.__file__)
# Out:
# /opt/anaconda3/envs/tot-llm/bin/python
# /Users/andrew/Tree-of-Thoughts_exps/tree-of-thought-llm/src/tot/__init__.py

# %%
task = Game24Task()
len(task), task.steps
# Out:
# (1362, 4)

# %%
x0 = task.get_input(0)
x0
# Out:
# '1 1 4 6'

# %%
dir(task)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'cot_prompt_wrap',
#  'data',
#  'get_input',
#  'propose_prompt_wrap',
#  'standard_prompt_wrap',
#  'steps',
#  'stops',
#  'test_output',
#  'value_cache',
#  'value_outputs_unwrap',
#  'value_prompt_wrap']
