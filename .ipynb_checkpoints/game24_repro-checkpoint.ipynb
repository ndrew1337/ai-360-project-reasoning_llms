# %%
import argparse
from tqdm import tqdm
import numpy as np
import sys

from tot.methods.bfs import solve, naive_solve
from tot.tasks.game24 import Game24Task

# %%
import sys
print(sys.executable)

import tot
print(tot.__file__)

# %%
task = Game24Task()
len(task)           # how many instances
task.steps          # depth (should be 3)
task.get_input(0)   # example (numbers)
